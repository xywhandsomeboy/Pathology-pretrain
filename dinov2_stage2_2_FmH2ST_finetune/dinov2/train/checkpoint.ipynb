# %%
import torch
torch.load("/home/li_yu/Proj04_he/done_work/dinov2_stage2_2_FmH2ST_finetune/dinov2/results/Grade/gcn5w_1112_pretrain_embeddings-1024-b4-mask75-finetune/last_checkpoint.rank_0")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 torch.load("/home/li_yu/Proj04_he/done_work/dinov2_stage2_2_FmH2ST_finetune/dinov2/results/Grade/gcn5w_1112_pretrain_embeddings-1024-b4-mask75-finetune/last_checkpoint.rank_0")
#
# File ~/miniconda3/envs/HE_DNA/lib/python3.10/site-packages/torch/serialization.py:815, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     813     except RuntimeError as e:
#     814         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 815 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/miniconda3/envs/HE_DNA/lib/python3.10/site-packages/torch/serialization.py:1033, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
# ...
